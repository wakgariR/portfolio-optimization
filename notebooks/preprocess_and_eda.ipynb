# %%
import sys
sys.path.append("../scripts")
from data_preprocessing import (
    fetch_data,
    clean_data,
    add_features,
    adf_test,
    calculate_var,
    calculate_sharpe_ratio,
    save_processed_data
)

# %% [markdown]
# Extract Historical Financial Data and Data Cleaning and Understanding

# %%
TICKERS = ["TSLA", "BND", "SPY"]
START_DATE = "2015-01-01"
END_DATE = "2026-01-15"

# Fetch
raw_df = fetch_data(TICKERS, START_DATE, END_DATE)

# Clean
clean_df = clean_data(raw_df)

# Feature engineering
processed_df = add_features(clean_df)
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['TSLA']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['BND']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# ['SPY']: YFRateLimitError('Too Many Requests. Rate limited. Try after a while.')
# d:\10Academy\week_9\portfolio-optimization\notebooks\../scripts\data_preprocessing.py:26: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df = df.fillna(method="ffill")
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10212\1637149535.py in ?()
#       8 # Clean
#       9 clean_df = clean_data(raw_df)
#      10
#      11 # Feature engineering
# ---> 12 processed_df = add_features(clean_df)
#
# d:\10Academy\week_9\portfolio-optimization\notebooks\../scripts\data_preprocessing.py in ?(df, volatility_window)
#      31 def add_features(df, volatility_window=30):
#      32     """Add daily returns and rolling volatility."""
# ---> 33     df["Daily_Return"] = df.groupby("Asset")["Adj Close"].pct_change()
#      34     df["Rolling_Volatility"] = (
#      35         df.groupby("Asset")["Daily_Return"]
#      36         .rolling(window=volatility_window)
#
# c:\Users\hp\miniconda3\envs\jupyter_env\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4308             self._setitem_frame(key, value)
#    4309         elif isinstance(key, (Series, np.ndarray, list, Index)):
#    4310             self._setitem_array(key, value)
#    4311         elif isinstance(value, DataFrame):
# -> 4312             self._set_item_frame_value(key, value)
#    4313         elif (
#    4314             is_list_like(value)
#    4315             and not self.columns.is_unique
#
# c:\Users\hp\miniconda3\envs\jupyter_env\Lib\site-packages\pandas\core\frame.py in ?(self, key, value)
#    4466
#    4467             return self.isetitem(locs, value)
#    4468
#    4469         if len(value.columns) > 1:
# -> 4470             raise ValueError(
#    4471                 "Cannot set a DataFrame with multiple columns to the single "
#    4472                 f"column {key}"
#    4473             )
#
# ValueError: Cannot set a DataFrame with multiple columns to the single column Daily_Return
